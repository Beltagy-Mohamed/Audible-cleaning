# %% [markdown]
# <a href="https://www.kaggle.com/code/beltagymohamedsaleh/audible-cleaning?scriptVersionId=196552044" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Import Data & Libraries

# %%
import pandas as pd

# %%
df = pd.read_csv("/kaggle/input/audible-dataset/audible_uncleaned.csv")

# %% [markdown]
# # Data Exploratory & Cleaning

# %%
df.head()
# Out:
#                                          name                     author  \
# 0                  Geronimo Stilton #11 & #12  Writtenby:GeronimoStilton
# 1                            The Burning Maze      Writtenby:RickRiordan
# 2                                The Deep End       Writtenby:JeffKinney
# 3                        Daughter of the Deep      Writtenby:RickRiordan
# 4  The Lightning Thief: Percy Jackson, Book 1      Writtenby:RickRiordan
#
#                     narrator                time releasedate language  \
# 0      Narratedby:BillLobely   2 hrs and 20 mins    04-08-08  English
# 1   Narratedby:RobbieDaymond   13 hrs and 8 mins    01-05-18  English
# 2      Narratedby:DanRussell    2 hrs and 3 mins    06-11-20  English
# 3  Narratedby:SoneelaNankani  11 hrs and 16 mins    05-10-21  English
# 4  Narratedby:JesseBernstein              10 hrs    13-01-10  English
#
#                            stars   price
# 0     5 out of 5 stars34 ratings  468.00
# 1   4.5 out of 5 stars41 ratings  820.00
# 2   4.5 out of 5 stars38 ratings  410.00
# 3   4.5 out of 5 stars12 ratings  615.00
# 4  4.5 out of 5 stars181 ratings  820.00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87489 entries, 0 to 87488
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         87489 non-null  object
#  1   author       87489 non-null  object
#  2   narrator     87489 non-null  object
#  3   time         87489 non-null  object
#  4   releasedate  87489 non-null  object
#  5   language     87489 non-null  object
#  6   stars        87489 non-null  object
#  7   price        87489 non-null  object
# dtypes: object(8)
# memory usage: 5.3+ MB

# %% [markdown]
# ### found that all columns are of type object. I will clean and convert relevant columns to appropriate types (e.g., date, numeric) and extract useful information from stars and time.

# %% [markdown]
# ##  Clean the 'author' and 'narrator' columns by removing specific prefixes and trimming extra spaces.
# ## The 'replace' method is used to remove 'Writtenby:' from the 'author' column and 'Narratedby:' from the 'narrator' column.
# ## The 'strip' method removes any leading or trailing whitespace.

# %%
df['Author'] = df['author'].str.replace('Writtenby:', '', regex=False).str.strip() #replace & regular expressions & delete any spaces
df['Narrator'] = df['narrator'].str.replace('Narratedby:', '', regex=False).str.strip()

# %%
df.head()
# Out:
#                                          name                     author  \
# 0                  Geronimo Stilton #11 & #12  Writtenby:GeronimoStilton
# 1                            The Burning Maze      Writtenby:RickRiordan
# 2                                The Deep End       Writtenby:JeffKinney
# 3                        Daughter of the Deep      Writtenby:RickRiordan
# 4  The Lightning Thief: Percy Jackson, Book 1      Writtenby:RickRiordan
#
#                     narrator                time releasedate language  \
# 0      Narratedby:BillLobely   2 hrs and 20 mins    04-08-08  English
# 1   Narratedby:RobbieDaymond   13 hrs and 8 mins    01-05-18  English
# 2      Narratedby:DanRussell    2 hrs and 3 mins    06-11-20  English
# 3  Narratedby:SoneelaNankani  11 hrs and 16 mins    05-10-21  English
# 4  Narratedby:JesseBernstein              10 hrs    13-01-10  English
#
#                            stars   price           Author        Narrator
# 0     5 out of 5 stars34 ratings  468.00  GeronimoStilton      BillLobely
# 1   4.5 out of 5 stars41 ratings  820.00      RickRiordan   RobbieDaymond
# 2   4.5 out of 5 stars38 ratings  410.00       JeffKinney      DanRussell
# 3   4.5 out of 5 stars12 ratings  615.00      RickRiordan  SoneelaNankani
# 4  4.5 out of 5 stars181 ratings  820.00      RickRiordan  JesseBernstein

# %% [markdown]
# ## Drop the old columns "author" and "narrator".

# %%
df.drop(["author", "narrator"], axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['name', 'time', 'releasedate', 'language', 'stars', 'price', 'Author',
#        'Narrator'],
#       dtype='object')

# %%
df.shape
# Out:
# (87489, 8)

# %%
df.isnull().sum()
# Out:
# name           0
# time           0
# releasedate    0
# language       0
# stars          0
# price          0
# Author         0
# Narrator       0
# dtype: int64

# %% [markdown]
# ## Clean the 'stars' column by removing the text 'out of 5 stars' and stripping any extra spaces.
# ## The 'replace' method removes the specified text, and 'strip' ensures there are no leading or trailing whitespace.

# %%
df['stars'] = df['stars'].str.replace('out of 5 stars', '', regex=False).str.strip()

# %% [markdown]
# ## Extract the numeric rating from the 'stars' column by splitting the string on whitespace and selecting the first element.
# ## This assumes the rating is the first part of the split result.

# %%
df['stars'] = df['stars'].str.split().str[0]

# %%
df.columns
# Out:
# Index(['name', 'time', 'releasedate', 'language', 'stars', 'price', 'Author',
#        'Narrator'],
#       dtype='object')

# %% [markdown]
# ## Convert 'price' column to numeric format for consistent analysis.
# ## Replace 'Free' with '0' to represent free items as zero, then remove any commas from the 'price' values.
# ## Convert the series to a string type for cleaning, and then to float for numerical analysis.

# %%
df['Price'] = df['price'].replace('Free', '0').astype(str).str.replace(',', '') # Convert the series to a string type before using the .str accessor
df['Price'] = df['Price'].astype(float) # Convert the 'Price' column to float

# %% [markdown]
# ## Convert the 'releasedate' column to datetime format for easier date manipulation and analysis.
# ## The 'format' parameter specifies that the date format is day-month-year (e.g., '31-12-23').

# %%
df['Releasedate'] = pd.to_datetime(df['releasedate'], format='%d-%m-%y')

# %% [markdown]
# ## Define a function to convert time strings into total minutes.
# ## The function splits the time string into hours and minutes, converts them to integers, and calculates the total minutes.
# ## The 'apply' method is then used to apply this function to the 'time' column and create a new column 'Time_in_Minutes'.

# %%
def convert_time_to_minutes(time_str):
    time_parts = time_str.split(' and ')
    hours = int(time_parts[0].split(' hrs')[0]) if 'hrs' in time_parts[0] else 0
    minutes = int(time_parts[1].split(' mins')[0]) if len(time_parts) > 1 and 'mins' in time_parts[1] else 0
    return hours * 60 + minutes

# Check for typos and correct the column name
df['Time_in_Minutes'] = df['time'].apply(convert_time_to_minutes)

# %%
df
# Out:
#                                              name                time  \
# 0                      Geronimo Stilton #11 & #12   2 hrs and 20 mins
# 1                                The Burning Maze   13 hrs and 8 mins
# 2                                    The Deep End    2 hrs and 3 mins
# 3                            Daughter of the Deep  11 hrs and 16 mins
# 4      The Lightning Thief: Percy Jackson, Book 1              10 hrs
# ...                                           ...                 ...
# 87484                   Last Days of the Bus Club   7 hrs and 34 mins
# 87485                                    The Alps   10 hrs and 7 mins
# 87486                        The Innocents Abroad   19 hrs and 4 mins
# 87487                       A Sentimental Journey    4 hrs and 8 mins
# 87488                                      Havana     6 hrs and 1 min
#
#       releasedate language stars   price           Author        Narrator  \
# 0        04-08-08  English     5  468.00  GeronimoStilton      BillLobely
# 1        01-05-18  English   4.5  820.00      RickRiordan   RobbieDaymond
# 2        06-11-20  English   4.5  410.00       JeffKinney      DanRussell
# 3        05-10-21  English   4.5  615.00      RickRiordan  SoneelaNankani
# 4        13-01-10  English   4.5  820.00      RickRiordan  JesseBernstein
# ...           ...      ...   ...     ...              ...             ...
# 87484    09-03-17  English   Not  596.00     ChrisStewart    ChrisStewart
# 87485    21-02-17  English   Not  820.00    StephenO'Shea      RobertFass
# 87486    30-12-16  English   Not  938.00        MarkTwain       FloGibson
# 87487    23-02-11  English   Not  680.00   LaurenceSterne     AntonLesser
# 87488    07-03-17  English   Not  569.00    MarkKurlansky     FleetCooper
#
#        Price Releasedate  Time_in_Minutes
# 0      468.0  2008-08-04              140
# 1      820.0  2018-05-01              788
# 2      410.0  2020-11-06              123
# 3      615.0  2021-10-05              676
# 4      820.0  2010-01-13              600
# ...      ...         ...              ...
# 87484  596.0  2017-03-09              454
# 87485  820.0  2017-02-21              607
# 87486  938.0  2016-12-30             1144
# 87487  680.0  2011-02-23              248
# 87488  569.0  2017-03-07              360
#
# [87489 rows x 11 columns]

# %% [markdown]
# ## Remove the 'time' column from the DataFrame as it is no longer needed after conversion to minutes.
# ## The 'axis=1' parameter specifies that we are dropping a column, and 'inplace=True' updates the DataFrame in place.

# %%
df.drop(["time"],axis=1,inplace=True)

# %%
df
# Out:
#                                              name releasedate language stars  \
# 0                      Geronimo Stilton #11 & #12    04-08-08  English     5
# 1                                The Burning Maze    01-05-18  English   4.5
# 2                                    The Deep End    06-11-20  English   4.5
# 3                            Daughter of the Deep    05-10-21  English   4.5
# 4      The Lightning Thief: Percy Jackson, Book 1    13-01-10  English   4.5
# ...                                           ...         ...      ...   ...
# 87484                   Last Days of the Bus Club    09-03-17  English   Not
# 87485                                    The Alps    21-02-17  English   Not
# 87486                        The Innocents Abroad    30-12-16  English   Not
# 87487                       A Sentimental Journey    23-02-11  English   Not
# 87488                                      Havana    07-03-17  English   Not
#
#         price           Author        Narrator  Price Releasedate  \
# 0      468.00  GeronimoStilton      BillLobely  468.0  2008-08-04
# 1      820.00      RickRiordan   RobbieDaymond  820.0  2018-05-01
# 2      410.00       JeffKinney      DanRussell  410.0  2020-11-06
# 3      615.00      RickRiordan  SoneelaNankani  615.0  2021-10-05
# 4      820.00      RickRiordan  JesseBernstein  820.0  2010-01-13
# ...       ...              ...             ...    ...         ...
# 87484  596.00     ChrisStewart    ChrisStewart  596.0  2017-03-09
# 87485  820.00    StephenO'Shea      RobertFass  820.0  2017-02-21
# 87486  938.00        MarkTwain       FloGibson  938.0  2016-12-30
# 87487  680.00   LaurenceSterne     AntonLesser  680.0  2011-02-23
# 87488  569.00    MarkKurlansky     FleetCooper  569.0  2017-03-07
#
#        Time_in_Minutes
# 0                  140
# 1                  788
# 2                  123
# 3                  676
# 4                  600
# ...                ...
# 87484              454
# 87485              607
# 87486             1144
# 87487              248
# 87488              360
#
# [87489 rows x 10 columns]

# %% [markdown]
# ## Add a space between lowercase and uppercase letters in the 'Author' and 'Narrator' columns to improve readability.
# ## The regular expression r'([a-z])([A-Z])' identifies lowercase letters followed by uppercase letters and inserts a space between them.
# ## The 'regex=True' parameter ensures that the replacement is done using regular expressions.

# %%
df['Author'] = df['Author'].str.replace(r'([a-z])([A-Z])', r'\1 \2', regex=True)
df['Narrator'] = df['Narrator'].str.replace(r'([a-z])([A-Z])', r'\1 \2',regex=True)

print(df['Author'].head())
# Out:
# 0    Geronimo Stilton
# 1        Rick Riordan
# 2         Jeff Kinney
# 3        Rick Riordan
# 4        Rick Riordan
# Name: Author, dtype: object

# %%
df
# Out:
#                                              name releasedate language stars  \
# 0                      Geronimo Stilton #11 & #12    04-08-08  English     5
# 1                                The Burning Maze    01-05-18  English   4.5
# 2                                    The Deep End    06-11-20  English   4.5
# 3                            Daughter of the Deep    05-10-21  English   4.5
# 4      The Lightning Thief: Percy Jackson, Book 1    13-01-10  English   4.5
# ...                                           ...         ...      ...   ...
# 87484                   Last Days of the Bus Club    09-03-17  English   Not
# 87485                                    The Alps    21-02-17  English   Not
# 87486                        The Innocents Abroad    30-12-16  English   Not
# 87487                       A Sentimental Journey    23-02-11  English   Not
# 87488                                      Havana    07-03-17  English   Not
#
#         price            Author         Narrator  Price Releasedate  \
# 0      468.00  Geronimo Stilton      Bill Lobely  468.0  2008-08-04
# 1      820.00      Rick Riordan   Robbie Daymond  820.0  2018-05-01
# 2      410.00       Jeff Kinney      Dan Russell  410.0  2020-11-06
# 3      615.00      Rick Riordan  Soneela Nankani  615.0  2021-10-05
# 4      820.00      Rick Riordan  Jesse Bernstein  820.0  2010-01-13
# ...       ...               ...              ...    ...         ...
# 87484  596.00     Chris Stewart    Chris Stewart  596.0  2017-03-09
# 87485  820.00    Stephen O'Shea      Robert Fass  820.0  2017-02-21
# 87486  938.00        Mark Twain       Flo Gibson  938.0  2016-12-30
# 87487  680.00   Laurence Sterne     Anton Lesser  680.0  2011-02-23
# 87488  569.00    Mark Kurlansky     Fleet Cooper  569.0  2017-03-07
#
#        Time_in_Minutes
# 0                  140
# 1                  788
# 2                  123
# 3                  676
# 4                  600
# ...                ...
# 87484              454
# 87485              607
# 87486             1144
# 87487              248
# 87488              360
#
# [87489 rows x 10 columns]

# %% [markdown]
# ## Remove the 'price' and 'releasedate' columns from the DataFrame as they are no longer needed for analysis after we add "Price"	"Releasedate".
# ## The 'axis=1' parameter specifies that we are dropping columns, and 'inplace=True' updates the DataFrame directly.

# %%
df.drop(["price"], axis=1, inplace=True)
df.drop(['releasedate'], axis=1,inplace=True)

# %% [markdown]
# ## Filter out rows where the 'stars' column has the value 'Not', as these entries are not useful for analysis.
# ## Reset the index after filtering to maintain a continuous index sequence.

# %%
df = df[df['stars'] != 'Not'].reset_index(drop=True)

# %%
df.isna().sum()
df.isnull().sum()
# Out:
# name               0
# language           0
# stars              0
# Author             0
# Narrator           0
# Price              0
# Releasedate        0
# Time_in_Minutes    0
# dtype: int64

# %% [markdown]
# # Display the number of missing values for each column in the DataFrame.
# # This helps identify if any columns need further cleaning or imputation before analysis.

# %%
df
# Out:
#                                              name language stars  \
# 0                      Geronimo Stilton #11 & #12  English     5
# 1                                The Burning Maze  English   4.5
# 2                                    The Deep End  English   4.5
# 3                            Daughter of the Deep  English   4.5
# 4      The Lightning Thief: Percy Jackson, Book 1  English   4.5
# ...                                           ...      ...   ...
# 15067                                  Why We Fly  English     5
# 15068                                  River Town  English     5
# 15069                      Figures in a Landscape  English     4
# 15070                             Tower of London  English     5
# 15071                          Tigers in the Snow  English     5
#
#                   Author           Narrator  Price Releasedate  \
# 0       Geronimo Stilton        Bill Lobely  468.0  2008-08-04
# 1           Rick Riordan     Robbie Daymond  820.0  2018-05-01
# 2            Jeff Kinney        Dan Russell  410.0  2020-11-06
# 3           Rick Riordan    Soneela Nankani  615.0  2021-10-05
# 4           Rick Riordan    Jesse Bernstein  820.0  2010-01-13
# ...                  ...                ...    ...         ...
# 15067          Evan Rail          Evan Rail  100.0  2014-06-23
# 15068      Peter Hessler      Peter Berkrot  836.0  2010-05-04
# 15069       Paul Theroux  Edoardo Ballerini  949.0  2018-06-07
# 15070            i Minds       Abbey Holmes   33.0  2009-12-23
# 15071  Peter Matthiessen     George Guidall  702.0  2004-08-05
#
#        Time_in_Minutes
# 0                  140
# 1                  788
# 2                  123
# 3                  676
# 4                  600
# ...                ...
# 15067                0
# 15068              876
# 15069             1004
# 15070                0
# 15071              294
#
# [15072 rows x 8 columns]

# %% [markdown]
# # Thank You
